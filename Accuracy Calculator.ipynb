# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path
import os
import glob as gb

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Mounting Drive for getting dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_df = '/content/drive/MyDrive/Capstone_Project/Data/Test'
test_generator = test_datagen.flow_from_directory(
    test_df,
    target_size=(256, 256),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=16
)
# Out:
# Found 27 images belonging to 9 classes.

# %%
model = tf.keras.models.load_model('/content/drive/MyDrive/Capstone_Project/Models/ResNet.h5')
results = model.evaluate(test_generator)
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
# 2/2 [==============================] - 7s 2s/step - loss: 8.7743 - accuracy: 0.1111
# Test Accuracy: 11.11%
